# %% [markdown]
# # Python Function

# %%
l = [1,0,4,1,2,4,2]
sorted(l)
l.sort()

# %%
sorted("Himal")
# Out:
# ['H', 'a', 'i', 'l', 'm']

# %%
def arg(x,y,*z):
  sum = x + y
  for i in z:
    sum += i
  else:
    print(sum)

arg(4,3,4,3,2,34,234,2,34)
# Out:
# 320

# %%
def argg(name,city,**dictn):
  d = {"name":name,"city":city}
  d.update(dictn)
  print(d)
argg(name="Himal",city="ahmedabad",age=20,profile="developer")
# Out:
# {'name': 'Himal', 'city': 'ahmedabad', 'age': 20, 'profile': 'developer'}

# %%
type(argg)
# Out:
# function

# %%
for i in range(1,11):
    if i % 2 == 0:
      print("  " * (10-i) + "/ " * i,end="   ")
      print("" * (10+i) + "\\ " * i)
    else:
      print("  " * (10-i) + "\\ " * i,end="   ")
      print("" * (10+i) + "/ " * i)
  # print(' ' * (11-i) + ' ' * i)
  # print(" " * (11+i) + "\\" * i)

# for i in range(1,11):
#   print("  " * (10-i) + "/" * i)
  
# for i in range(1,11):
#   print(" " * (10-i) + "/" * i)
# Out:
#                   \    /
#                 / /    \ \
#               \ \ \    / / /
#             / / / /    \ \ \ \
#           \ \ \ \ \    / / / / /
#         / / / / / /    \ \ \ \ \ \
#       \ \ \ \ \ \ \    / / / / / / /
#     / / / / / / / /    \ \ \ \ \ \ \ \
#   \ \ \ \ \ \ \ \ \    / / / / / / / / /
# / / / / / / / / / /    \ \ \ \ \ \ \ \ \ \

# %%
# lambada function : this keyword is used to make annonymous function.
# In other scenario if we store any function in other variable then the function
# pass his reference to the variable and change the name of that funcition.
# But in lambda function if we do the same thing then the reference is not going
# to pass to any variable. It will only pass function definition with same name
# that we have used in making of lambda function.

# A lambda function is a small anonymous function.
# A lambda function can take any number of arguments, but can only have one expression.

lam = lambda x : x % 2 == 0

# %%
z = lambda y : y % 2 == 0

# %%
z(5)
# Out:
# False

# %%
help(z)
# Out:
# Help on function <lambda> in module __main__:
#
# <lambda> lambda y

# %%
x = z
print(x)
# Out:
# <function <lambda> at 0x7f91fe6fb050>

# %%
help(x)
# Out:
# Help on function <lambda> in module __main__:
#
# <lambda> lambda y

# %%
help(z)
# Out:
# Help on function <lambda> in module __main__:
#
# <lambda> lambda y

# %%
# List comprehension --> 
# newlist = [expression for item in iterable if condition == True]

l = [34,2,1,4,4,2,33]
j = [x for x in l if x >= 10]
for i in l:
  True if i >= 10 else False
# lamb = lambda x: True if x >= 10 else False
# lamb(10)

# %%
add = lambda x,y : x+y
add
# Out:
# <function __main__.<lambda>>

# %%
type(add)
# Out:
# function

# %%
def add2(x,y):
  return x+y
add2
# Out:
# <function __main__.add2>

# %%
abc = add

# %%
abc
# Out:
# <function __main__.<lambda>>

# %%
xyz = add2
xyz
# Out:
# <function __main__.add2>

# %%
# One line conditional statement

# %%
"Yes" if 10 == 20 else "No bro"
# Out:
# 'No bro'

# %%
# Lambda function with one line conditional statement 
lab = lambda x: True if x == 2 else False

# %%
lab
# Out:
# <function __main__.<lambda>>

# %%
lab(2)
# Out:
# True

# %% [markdown]
# ## DECORATORS
# #### A decorator is a design pattern in Python that allows a user to add new functionality to an existing object without modifying its structure. Decorators are usually called before the definition of a function you want to decorate.

# %%
def decorator1(func1):
  def dec_execute():
    print("-----------------------------------------------------------------------")
    func1()
    print("-----------------------------------------------------------------------")
  return dec_execute()

@decorator1
def himal():
  print("I want decoration before and after this line.")
# Out:
# -----------------------------------------------------------------------
# I want decoration before and after this line.
# -----------------------------------------------------------------------
