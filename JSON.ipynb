# %% [markdown]
# # PYTHON JSON
# #### JSON is a syntax for storing and exchanging data.
# #### JSON is text, written with JavaScript object notation.
# #### JSON (JavaScript Object Notation) is a popular data format used for representing structured data.
# #### It's common to transmit and receive data between a server and web application in JSON format.
# #### The json module makes it easy to parse JSON strings and files containing JSON object.

# %%
import json

# %%
json_str = '{"name":"himal","age":20,"exp":"5_year"}'
# print(json_str)
# Out:
# {"name":"himal","age":20,"exp":"5_year"}

# %%
# If you have a JSON string, you can parse it by using the json.loads() method.
py_dict = json.loads(json_str)
print(py_dict)
# Out:
# {'name': 'himal', 'age': 20, 'exp': '5_year'}

# %%
type(py_dict)
# Out:
# dict

# %%
py_dict = {"Name":"Himal","Age":20,"Role":"Programmer","car":[\
    {"Brand":"Mercedes","color":"red"}, 
    {"Brand":"Nexon","color":"black"}, 
  ]}

# %%
# If you have a Python object, you can convert it into a JSON string by using the json.dumps() method.
# Indent parameter is used to define the number of indent. 
# You can also define the separators, default value is (", ", ": ")
# This method has sortkeys parameters to order the keys in the result:

json_str = json.dumps(py_dict,indent=4,separators=(". "," = "),sort_keys=True)
print(json_str)
# Out:
# {
#     "Age" = 20.
#     "Name" = "Himal".
#     "Role" = "Programmer".
#     "car" = [
#         {
#             "Brand" = "Mercedes".
#             "color" = "red"
#         }.
#         {
#             "Brand" = "Nexon".
#             "color" = "black"
#         }
#     ]
# }

# %%
|
